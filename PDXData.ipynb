# %%
#Check 911-calls.csv
data_911 =pd.read_csv('911-calls.csv')

# %%
import pandas as pd
import numpy as np
#import scipy
#import sklearn
import matplotlib.pyplot as plt

# %%
#test= data_911.isnull().any(axis=1)
#clean data drop NAN
afterdrop =data_911.dropna()
#neighborhood number
neighborhoods = afterdrop['Neighborhood'].unique()
total_neighborhoods =len(neighborhoods)
#byneighborhoods= afterdrop.groupby('Neighborhood')
#print(data_911["Call Category"].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f69312b7c400> in <module>()
#       1 #test= data_911.isnull().any(axis=1)
#       2 #clean data drop NAN
# ----> 3 afterdrop =data_911.dropna()
#       4 #neighborhood number
#       5 neighborhoods = afterdrop['Neighborhood'].unique()
#
# NameError: name 'data_911' is not defined

# %%
crime_neighborhood_response_df = data_911[['Neighborhood', 'Response Time (sec)','Travel Time (sec)']].dropna(subset=['Response Time (sec)'])#.groupby('Neighborhood').count().iloc[:,0]

# %%
crime_neighborhood_response_df.head(5)

# %%
#Get mean response time and count statistics associated with each neighborhood
crime_neighborhood_response_incidents = crime_neighborhood_response_df.groupby(['Neighborhood']).agg(['mean', 'count'])
#crime_neighborhood_response_incidents = crime_neighborhood_response_df.groupby(['Neighborhood']).agg(['mean', 'count'])

# %%
crime_neighborhood_response_incidents.head(2)

# %%
crime_neighborhood_response_incidents.head(2).plot(kind='bar',figsize=(30,10))#camis_count.plot(kind='hist',bins=20)
plt._show()

# %%
data_911.columns

# %%
data_911.head()

# %%
data_event=pd.read_csv('events_day.csv')
data_event.head()

# %%
data_house=pd.read_csv('housing.csv')
data_house.shape

# %%
data_messages=pd.read_csv('messages.csv')
data_messages.head()
# Out:
#    messageCode                              signMessageLong
# 0            0                                          NaN
# 1          451  MAX  Blue Line to City Center and Hillsboro
# 2          452                        MAX  Blue Line to PSU
# 3          453                         MAX  Red Line to PSU
# 4          454    MAX  to Gresham - MAX to Portland Airport

# %%
data_meta=pd.read_csv('meta.csv')
data_meta.head()
# Out:
#        city  inCongestion  loadPercentage  newTrip  offRoute   state  system  \
# 0  portland         False               0    False     False  oregon  trimet
#
#    type
# 0  rail

# %%
data_trips=pd.read_csv('trips_day.csv')
data_trips.head()
# Out:
#     tripID  vehicle_id  blockID  direction garage  messageCode  routeNumber
# 0  7126389         115     9040          0   ELMO          927           90
# 1  7126389         201     9040          0   ELMO          927           90
# 2  7126389         209     9040          0   ELMO          927           90
# 3  7126389         242     9040          0   ELMO          927           90
# 4  7126390         222     9041          0   ELMO          927           90

# %%
data_clean=pd.read_csv("trimetridership_cleaned.csv")
data_clean.head()
# Out:
#   #Trimet Ridership Data extracted from trimet.org/about/pdf/trimetridership.pdf   \
# 0                                            Heading
# 1                                  Originating Rides
# 2                                  Originating Rides
# 3                                  Originating Rides
# 4                                  Originating Rides
#
#       Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0  Key Indicator     FY2000     FY2001     FY2002     FY2003     FY2004
# 1            Bus   45956400   47905200   48148800   47790000   48394800
# 2            MAX   17652000   18579600   21218400   21801600   22890000
# 3        WES (1)        NaN        NaN        NaN        NaN        NaN
# 4   Fixed Route:   63608400   66484800   69367200   69591600   71284800
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0     FY2005     FY2006     FY2007      FY2008      FY2009      FY2010
# ...

# %%
data_housing =pd.read_csv('housing.csv')

# %%
data_housing.columns
# Out:
# Index(['Avg Sale To List', 'Avg Sale To List Mom', 'Avg Sale To List Yoy',
#        'Homes Sold', 'Homes Sold Mom', 'Homes Sold Yoy', 'Inventory',
#        'Inventory Mom', 'Inventory Yoy', 'Median Dom', 'Median Dom Mom',
#        'Median Dom Yoy', 'Median Sale Price', 'Median Sale Price Mom',
#        'Median Sale Price Yoy', 'New Listings', 'New Listings Mom',
#        'New Listings Yoy', 'Period End', 'Property Type', 'Region'],
#       dtype='object')

# %%
housingregion =data_housing['Region'].unique()
len(housingregion)
len(neighborhoods)
# Out:
# 79

# %%
#crime_neighborhood_response_df = data_911[['Neighborhood', 'Response Time (sec)']].dropna(subset=['Response Time (sec)'])#.groupb
#crime_neighborhood_response_incidents = crime_neighborhood_response_df.groupby(['Neighborhood']).agg(['mean', 'count'])crime_neighborhood_response_incidents = crime_neighborhood_response_df.groupby(['Neighborhood']).agg(['mean', 'count'])
#housing_df = data_housing.dropna()
#house_median =housing_df[['Region','Median Sale Price']]
#h =house_median.groupby(['Region']).agg(['mean'])

len(housingregion)
# Out:
# 97

# %%
housingregion
# Out:
# array(["Portland, OR - Sullivan's Gulch",
#        'Portland, OR - Lents-Powellhurst-Gilbert',
#        'Portland, OR - South Tabor', 'Portland, OR - Parkrose',
#        'Portland, OR - Eliot', 'Portland, OR - Kerns',
#        'Portland, OR - Argay', 'Portland, OR - Multnomah Village',
#        'Portland, OR - Lents', 'Portland, OR - North Tabor',
#        'Portland, OR - Hillside', 'Portland, OR - Cully',
#        'Portland, OR metro area', 'Portland, OR - Brentwood',
#        'Portland, OR - Downtown Portland', 'Portland, OR - King',
#        'Portland, OR - Cathedral Park', 'Portland, OR - Grant Park',
#        'Portland, OR - Center', 'Portland, OR - Eastmoreland',
#        'Portland, OR - Brooklyn', 'Portland, OR - Brentwood-Darlington',
#        'Portland, OR - Arnold Creek', 'Portland, OR - Russell',
#        'Portland, OR - West Portland Park', 'Portland, OR - Laurelhurst',
#        'Portland, OR - Hayden Island', 'Portland, OR',
# ...

# %%
neighborhoods
# Out:
# array(['Hosford-Abernethy', 'Powellhurst-Gilbert', 'Foster-Powell',
#        'Piedmont', 'Pearl', 'Downtown', 'West Portland Park',
#        'Buckman West', 'Overlook', 'Hollywood', 'Brooklyn', 'Sumner',
#        'Lloyd', 'Buckman East', 'Richmond', 'Montavilla',
#        'Rose City Park', 'Madison South', 'Eliot', 'Hazelwood',
#        'Woodstock', 'St Johns', 'Sellwood-Moreland', 'University Park',
#        'Concordia', 'Old Town/Chinatown', 'Wilkes',
#        'Northwest Industrial', 'Irvington', 'Goose Hollow', 'Cully',
#        'Kenton', 'Centennial', 'Kerns', 'Parkrose', 'Lents',
#        "Sullivan's Gulch", 'Sunnyside', 'Creston-Kenilworth', 'Hillsdale',
#        'Northwest', 'Laurelhurst', 'Cathedral Park', 'Mt Tabor', 'Reed',
#        'Portsmouth', 'Arbor Lodge', 'North Tabor', 'Mill Park',
#        'Homestead', 'Hayden Island', 'King', 'Beaumont-Wilshire',
#        'South Portland', 'Woodlawn', 'Humboldt', 'Vernon', 'Multnomah',
# ...

# %%
neighborhoods[0]
# Out:
# 'Hosford-Abernethy'

# %%
len(neighborhoods)
# Out:
# 79

# %%
#crime_neighborhood_response_df = data_911[['Neighborhood', 'Response Time (sec)']].dropna(subset=['Response Time (sec)'])#.groupb
#crime_neighborhood_response_incidents = crime_neighborhood_response_df.groupby(['Neighborhood']).agg(['mean', 'count'])crime_neighborhood_response_incidents = crime_neighborhood_response_df.groupby(['Neighborhood']).agg(['mean', 'count'])
housing_df = data_housing.dropna()
house_median =housing_df[['Region','Median Sale Price']]
house_median
h =house_median.groupby(['Region']).agg(['mean'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-169-58e058b4c4b0> in <module>()
#       4 house_median =housing_df[['Region','Median Sale Price']]
#       5 house_median
# ----> 6 h =house_median.groupby(['Region']).agg(['mean'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4656         axis=''))
#    4657     def aggregate(self, arg, *args, **kwargs):
# -> 4658         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4659
#    4660     agg = aggregate
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4087
#    4088         _level = kwargs.pop('_level', None)
# -> 4089         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    4090         if how is None:
#    4091             return result
#
# ...

# %%
housing_df = data_housing.dropna()
house_median =housing_df[['Region','Median Sale Price']]
house_median
h =house_median.groupby(['Region']).sum()

# %%
house_median['Median Sale Price']
# Out:
# 0       $398K
# 1       $156K
# 2       $271K
# 3       $248K
# 4       $550K
# 5       $352K
# 6       $253K
# 7       $266K
# 8       $255K
# 9       $170K
# 10      $853K
# 11      $425K
# 12      $375K
# 13      $252K
# 14      $190K
# 15      $373K
# 16      $450K
# 17      $350K
# 18      $333K
# 19      $282K
# 20      $775K
# 21      $228K
# 22      $390K
# 23      $687K
# 24      $345K
# 25      $640K
# 26      $200K
# 27      $242K
# 28      $231K
# 29      $291K
#         ...
# 7338    $404K
# 7339    $429K
# 7340    $305K
# 7341    $410K
# 7342    $335K
# 7343    $285K
# 7344    $500K
# 7345    $585K
# 7346    $300K
# 7347    $270K
# 7348    $240K
# 7349    $401K
# 7350    $332K
# 7351    $495K
# 7352    $329K
# 7353    $460K
# 7354    $273K
# 7355    $302K
# 7356    $410K
# 7357    $328K
# 7358    $288K
# 7359    $273K
# 7360    $242K
# 7361    $330K
# 7362    $530K
# 7363    $425K
# 7364    $747K
# 7365    $236K
# 7366    $740K
# 7367    $320K
# ...

# %%
housing_df
# Out:
#       Avg Sale To List Avg Sale To List Mom Avg Sale To List Yoy  Homes Sold  \
# 0             0.985435               -0.50%               -0.10%           8
# 1             0.984077               -0.70%               -0.40%          13
# 2             0.987811                1.00%                0.50%          28
# 3             1.042150                1.80%                4.60%          24
# 4             1.080477                5.40%                9.30%           7
# 5             0.980776                0.10%                2.60%          14
# 6             0.994220                1.40%                1.20%          26
# 7             0.972307                0.30%                0.90%          28
# 8             1.017105               -0.20%               -0.10%          87
# 9             1.148504                0.50%               15.00%           5
# 10            0.980800               -0.60%                1.90%          14
# ...

# %%
regions_1=housing_df['Region'].replace(to_replace='Portland, OR - *',value='',regex=True,inplace=True)
#r= housing_df['Region']+'try'

# %% [raw]
# #house= pd.DataFrame(housingregion)
# print(housingregion)

# %%
house= pd.DataFrame(housingregion)
house.replace(to_replace='Portland, OR - *',value='',regex=True,inplace=True)
print(house.head())

# %%
housing_df.head()
# Out:
#    Avg Sale To List Avg Sale To List Mom Avg Sale To List Yoy  Homes Sold  \
# 0          0.985435               -0.50%               -0.10%           8
# 1          0.984077               -0.70%               -0.40%          13
# 2          0.987811                1.00%                0.50%          28
# 3          1.042150                1.80%                4.60%          24
# 4          1.080477                5.40%                9.30%           7
#
#   Homes Sold Mom Homes Sold Yoy  Inventory Inventory Mom Inventory Yoy  \
# 0         14.30%         14.30%        9.0        50.00%        28.60%
# 1         -7.10%        333.30%       11.0       -26.70%       -26.70%
# 2         16.70%        154.50%        5.0       -54.50%       -68.80%
# 3         20.00%         33.30%       10.0        -9.10%       -23.10%
# 4          0.00%        -12.50%        1.0         0.00%       -92.90%
#
#    Median Dom            ...              Median Dom Yoy  Median Sale Price  \
# ...

# %%
def clean(x):
    x = x.replace("$", "").replace(",", "").replace(" ", "").replace("K","")
    return float(x)

# %%
## crime_neighborhood_response_df = data_911[['Neighborhood', 'Response Time (sec)']].dropna(subset=['Response Time (sec)'])#.groupb
#crime_neighborhood_response_incidents = crime_neighborhood_response_df.groupby(['Neighborhood']).agg(['mean', 'count'])crime_neighborhood_response_incidents = crime_neighborhood_response_df.groupby(['Neighborhood']).agg(['mean', 'count'])
housing_df = data_housing.dropna()
house_median =housing_df[['Region','Median Sale Price']]
 
#msp = 
house_median['Median Sale Price']= house_median['Median Sale Price'].apply(lambda x: x.replace("$", "").replace("K","").replace(',',''))
house_median['Median Sale Price']=house_median['Median Sale Price'].astype(int)
house_median.head()
#house_median['Median Sale Price']= msp
h =house_median.groupby(['Region']).agg(['mean'])
h.plot(kind='bar',figsize=(50,20))
plot.show()

#orders['item_price'] = orders.item_price.str.replace('$', '').astype(int)
#house_median['Median Sale Price']
#t=house_median.str.replace('$',"").replace('K',"").astype(float)
# Out:
# C:\Users\maria\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\maria\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-271-7b2a5d3a0f4d> in <module>()
#      11 h =house_median.groupby(['Region']).agg(['mean'])
# ...

# %%
#house_median['Region']
house_median['Region']=house_median['Region'].apply(lambda x: x.replace("Portland, OR -", ""))
house_median.head()

# %%
df =pd.DataFrame({'Map': [0,0,0,1,1,2,2],'Values': [1,2,3,4,5,6,7]})
print (df)
# Out:
#    Map  Values
# 0    0       1
# 1    0       2
# 2    0       3
# 3    1       4
# 4    1       5
# 5    2       6
# 6    2       7

# %%
df['S'] =df.groupby('Map')['Values'].transform(np.sum)

# %%
print(df)
# Out:
#    Map  Values   S
# 0    0       1   6
# 1    0       2   6
# 2    0       3   6
# 3    1       4   9
# 4    1       5   9
# 5    2       6  13
# 6    2       7  13

# %%
data = {'abc': 2, 'def': 2, 'xyz': 3,'ab': 1, 'de': 2, 'xy': 2}
ser = pd.Series(data)
ser1= ser *2
list=['1','a',1]

# %%
print(type(list))
s= pd.Series(['1','a',1])
ser1[1]
# Out:
# <class 'list'>
# 4

# %%
s
# Out:
# 0    1
# 1    a
# 2    1
# dtype: object

# %%
dates = pd.date_range('20170505', periods = 8)
print(dates)
# Out:
# DatetimeIndex(['2017-05-05', '2017-05-06', '2017-05-07', '2017-05-08',
#                '2017-05-09', '2017-05-10', '2017-05-11', '2017-05-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, t1, 'bo', t2, t2*t2, 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
#plt.style.use('seaborn-deep')

x = np.random.normal(1, 2, 5000)
y = np.random.normal(-1, 3, 2000)
bins = np.linspace(-10, 10, 10)
s1= pd.Series(x)
s2= pd.Series(y)
plt.hist([s1, s2,x,y], bins, label=['x', 'y'])
plt.legend(loc='upper right')
plt.show()

# %%
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
print(type(objects))
y_pos = np.arange(len(objects))
print(type(y_pos))
performance = [10,8,6,4,2,1]
#performance =[[10,9],[8,7],[6,3],[2,1],[1,1]]
print(type(performance))
plt.bar(objects, performance, align='center', alpha=0.5)
#plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
 
plt.show()
p2= performance *2
test = pd.DataFrame( y_pos,performance)
test.head()
# Out:
# <class 'tuple'>
# <class 'numpy.ndarray'>
# <class 'list'>
#     0
# 10  0
# 8   1
# 6   2
# 4   3
# 2   4

# %%
n =np.sort(neighborhoods)
print((n))
# Out:
# ['Arbor Lodge' 'Ardenwald' 'Argay' 'Arlington Heights' 'Beaumont-Wilshire'
#  'Boise' 'Brentwood-Darlington' 'Bridlemile' 'Brooklyn' 'Buckman East'
#  'Buckman West' 'Cathedral Park' 'Centennial' 'Concordia'
#  'Creston-Kenilworth' 'Cully' 'Downtown' 'Eastmoreland' 'Eliot'
#  'Far Southwest' 'Forest Park' 'Foster-Powell' 'Glenfair' 'Goose Hollow'
#  'Grant Park' 'Hayden Island' 'Hazelwood' 'Hillsdale' 'Hillside'
#  'Hollywood' 'Homestead' 'Hosford-Abernethy' 'Humboldt' 'Irvington'
#  'Kenton' 'Kerns' 'King' 'Laurelhurst' 'Lents' 'Linnton' 'Lloyd'
#  'Madison South' 'Maplewood' 'Mill Park' 'Montavilla' 'Mt Scott-Arleta'
#  'Mt Tabor' 'Multnomah' 'North Tabor' 'Northwest' 'Northwest Industrial'
#  'Old Town/Chinatown' 'Overlook' 'Parkrose' 'Parkrose Heights' 'Pearl'
#  'Piedmont' 'Portsmouth' 'Powellhurst-Gilbert' 'Reed' 'Richmond'
#  'Rose City Park' 'Roseway' 'Sellwood-Moreland' 'South Portland'
#  'South Tabor' 'Southwest Hills' 'St Johns' "Sullivan's Gulch" 'Sumner'
# ...

# %%
n1=set(n)

# %%
r =np.sort(housingregion)
print(len(r))
# Out:
# 97

# %%
r1= set(r)

# %%
print(len(n1))
# Out:
# 79

# %%
union = r1.union(n1)

# %%
print(len(union))
# Out:
# 117

# %%
inter1 = n1.intersection(r1)
print(inter1)
# Out:
# {'Eliot', 'Southwest Hills', 'Sunnyside', 'Grant Park', 'Roseway', 'Parkrose Heights', 'Boise', 'Lents', 'Richmond', 'Parkrose', 'Wilkes', 'Hayden Island', 'Montavilla', 'Reed', 'West Portland Park', 'Glenfair', 'Hillside', 'Kenton', 'Hazelwood', 'University Park', 'Eastmoreland', 'South Tabor', 'Far Southwest', 'Mill Park', 'Concordia', "Sullivan's Gulch", 'Homestead', 'Forest Park', 'Arbor Lodge', 'Woodlawn', 'North Tabor', 'Foster-Powell', 'Goose Hollow', 'Sylvan-Highlands', 'Overlook', 'Brooklyn', 'Bridlemile', 'Piedmont', 'Creston-Kenilworth', 'Irvington', 'Laurelhurst', 'Cathedral Park', 'Hosford-Abernethy', 'Sumner', 'King', 'Madison South', 'Beaumont-Wilshire', 'Centennial', 'Vernon', 'Humboldt', 'Brentwood-Darlington', 'Maplewood', 'Hillsdale', 'Powellhurst-Gilbert', 'Rose City Park', 'Woodstock', 'Argay', 'Kerns', 'Cully'}

# %%
inter2= r1.intersection(n1)
print(type(inter2))
# Out:
# <class 'set'>

# %%
inventory = ["beans", "coin", "tome",'a']
inventory
# Out:
# ['beans', 'coin', 'tome', 'a']

# %%
inventory[0]
# Out:
# 'beans'

# %%
hero = {
    "name": None,
    "species": "Human",
    "strength": 4,
    "magic": 5,
    "profession": None,
}
hero
# Out:
# {'name': None,
#  'species': 'Human',
#  'strength': 4,
#  'magic': 5,
#  'profession': None}

# %%
hero['name']

# %%
if hero["name"] is None:
    if hero["name"] is None:
    # We modify dictionary values just like we access them.
    hero["name"] = input("What is your name?")
    print("Fantastic, thanks {}".format(hero["name"]))
# Out:
#   File "<ipython-input-495-e862f5ca2475>", line 4
#     hero["name"] = input("What is your name?")
#        ^
# IndentationError: expected an indented block

# %%
print("Ok {}, you are a {} {}.".format(hero["name"], hero["species"], hero["profession"]))
# Out:
# Ok None, you are a Human None.

# %%
letters = ['a', 'b', 'c', 'd']
letters.append('e')

numbers = ['one', 'two', 'four']
numbers.insert(2, 'three')

to_do = ["Conquer world", "Install Linux", "Change light bulb"]
current_task = to_do.pop()

fowl = ['duck', 'duck', 'goose', 'duck']
goose_index = fowl.index('goose')

words = ['car', 'boat', 'apple', 'banana']
words.sort()

ids = [15, 26, 41, 1]
ids.sort()

# %%
to_do = ["Conquer world", "Install Linux", "Change light bulb"]
current_task = to_do.pop()

# %%
current_task

# %%
age = 5
while not isinstance(age, int):
    try:
        age = int(input("What is your age?"))
    except ValueError:
        print("Sorry, we were expecting an integer. Try again.")
    
print("Fantastic, thank you!")

# %%
def longest(words):
    # Your code here
    length = 0;
    for w in words:
      # if( w is not None):
          l = len(w)
          if(length < l):
             length = l
    return length

# %%
l = longest("Aa")

# %%
print(l)

# %%
ll=5

# %%
"hello".upper()

# %%
#print(data_911_drop_response_by_Neighborhood.columns)
#list(data_911_drop_response_by_Neighborhood)[1]
#response_mean = data_911_drop_response_by_Neighborhood.mean()
#response_count = data_911_drop_response_by_Neighborhood.count()
#response_count.head()
#print(response_mean.index)
#y = response_mean['Response Time (sec)']
#print(y)
#plt.scatter(response_mean.index, y)
#plt.xlabel('year of release')
#plt.ylabel('median rating');
midx = pd.MultiIndex(levels=[['lama', 'cow', 'falcon'], ['speed', 'weight', 'length']],labels=[[0, 0, 0, 1, 1, 1, 2, 2, 2],[0, 1, 2, 0, 1, 2, 0, 1, 2]])
                             
df = pd.DataFrame(index=midx, columns=['big', 'small'],data=[[45, 30], [200, 100], [1.5, 1], [30, 20], [250, 150], [1.5, 0.8], [320, 250], [1, 0.8], [0.3,0.2]])
print(midx)

# %%
events_month =pd.read_csv('events_month.csv')
events_month.head(10)
# Out:
#    bearing  delay      event_timestamp  lastLocID  lastStopSeq  nextLocID  \
# 0      306   -430  2017-01-01 08:00:03       9819           24       9827
# 1       20   -113  2017-01-01 08:00:04      13720            1      13721
# 2       91    -17  2017-01-01 08:00:22       9848            1       9846
# 3      358    -56  2017-01-01 08:00:23       9299            6       7763
# 4       98   -729  2017-01-01 08:00:23       8357           46       8359
# 5      168    -31  2017-01-01 08:00:32      13715           13      13716
# 6      180     -5  2017-01-01 08:00:38      11504            7      11505
# 7        3    -61  2017-01-01 08:01:00      13135            4      13136
# 8       90   -313  2017-01-01 08:01:33       7763            8       8340
# 9      178   -124  2017-01-01 08:01:35       7601           17       9303
#
#    nextStopSeq   tripID  vehicle_id  vehicle_location_latitude  \
# 0           25  6999629         251                  45.502307
# ...

# %%
localId_last = events_month['lastLocID'].max()
localId_last
# Out:
# 13803

# %%
localId_next = events_month['nextLocID'].max()
localId_next
# Out:
# 13803

# %%
#total 
rows=events_month['nextLocID'].count()
rows
# Out:
# 164441

# %%
last = events_month['lastLocID'].unique()
next =events_month['nextLocID'].unique()

# %%
print("total row ")
print(rows)
print("last total   min number   max number")
print(len(last), last.min(), last.max())
print("next toal")
print(len(next), next.min(), next.max())
# Out:
# total row
# 164441
# last total   min number   max number
# 172 7601 13803
# next toal
# 172 7601 13803

# %%
s_last =np.sort(last)
s_next =np.sort(next)

# %%
s_last
# Out:
# array([ 7601,  7606,  7608,  7618,  7627,  7646,  7763,  7774,  7777,
#         7787,  8333,  8334,  8335,  8336,  8337,  8338,  8339,  8340,
#         8341,  8342,  8343,  8344,  8345,  8346,  8347,  8348,  8349,
#         8350,  8351,  8352,  8353,  8354,  8355,  8356,  8357,  8359,
#         8360,  8361,  8362,  8363,  8364,  8365,  8366,  8367,  8368,
#         8369,  8370,  8371,  8372,  8373,  8374,  8375,  8376,  8377,
#         8378,  8379,  8380,  8381,  8382,  8383,  8384,  9299,  9303,
#         9624,  9757,  9758,  9759,  9818,  9819,  9820,  9821,  9822,
#         9823,  9824,  9825,  9826,  9827,  9828,  9829,  9830,  9831,
#         9832,  9833,  9834,  9835,  9836,  9837,  9838,  9839,  9840,
#         9841,  9842,  9843,  9844,  9845,  9846,  9848,  9969, 10117,
#        10118, 10120, 10121, 10293, 10572, 10573, 10574, 10575, 10576,
#        10577, 10579, 11498, 11499, 11500, 11501, 11502, 11503, 11504,
# ...

# %%
s_next
# Out:
# array([ 7601,  7606,  7608,  7618,  7627,  7646,  7763,  7774,  7777,
#         7787,  8333,  8334,  8335,  8336,  8337,  8338,  8339,  8340,
#         8341,  8342,  8343,  8344,  8345,  8346,  8347,  8348,  8349,
#         8350,  8351,  8352,  8353,  8354,  8355,  8356,  8357,  8359,
#         8360,  8361,  8362,  8363,  8364,  8365,  8366,  8367,  8368,
#         8369,  8370,  8371,  8372,  8373,  8374,  8375,  8376,  8377,
#         8378,  8379,  8380,  8381,  8382,  8383,  8384,  9299,  9303,
#         9624,  9757,  9758,  9759,  9818,  9819,  9820,  9821,  9822,
#         9823,  9824,  9825,  9826,  9827,  9828,  9829,  9830,  9831,
#         9832,  9833,  9834,  9835,  9836,  9837,  9838,  9839,  9840,
#         9841,  9842,  9843,  9844,  9845,  9846,  9848,  9969, 10117,
#        10118, 10120, 10121, 10293, 10572, 10573, 10574, 10575, 10576,
#        10577, 10579, 11498, 11499, 11500, 11501, 11502, 11503, 11504,
# ...

# %%
t = s_last==s_next

# %%
t
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
events_week =pd.read_csv('events_week.csv')

# %%
rows_week=events_week['nextLocID'].count()
print(rows_week, rows)
# Out:
# 234332 164441

# %%
last_week = events_week['lastLocID'].unique()
next_week =events_week['nextLocID'].unique()

# %%
print("total row ")
print(rows)
print("last total   min number   max number")
print(len(last), last.min(), last.max())
print("next toal")
print(len(next), next.min(), next.max())
# Out:
# total row
# 164441
# last total   min number   max number
# 172 7601 13803
# next toal
# 172 7601 13803

# %%
print("total row_week ")
print(rows_week)
print("last total   min number   max number")
print(len(last_week), last_week.min(), last_week.max())
print("next toal")
print(len(next_week), next_week.min(), next_week.max())
# Out:
# total row_week
# 234332
# last total   min number   max number
# 172 7601 13803
# next toal
# 172 7601 13803

# %%
thisdict =	{
 
}
thisdict["apple"] = "red"
thisdict[1] = "red"
i=10
thisdict[i] = "red_red"
print(thisdict)
# Out:
# {'apple': 'red', 1: 'red', 10: 'red_red'}

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ...:                           'foo', 'bar', 'foo', 'foo'],
   ...:                    'B' : ['one', 'one', 'two', 'three',
   ...:                           'two', 'two', 'one', 'four'],
   ...:                    'C' : np.random.randn(8),
   ...:                    'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.347626  0.008619
# 1  bar    one -0.562686  0.921941
# 2  foo    two -0.016330  1.142171
# 3  bar  three -0.146382 -1.397760
# 4  foo    two  0.149273 -0.915715
# 5  bar    two  0.006052 -1.100953
# 6  foo    one  2.317197 -1.136477
# 7  foo   four -1.284365 -0.143604

# %%
grouped = df.groupby(["A","B"])
dic ={}
for name, group in grouped:
        print("name ", name)
        print("group", group)
        print("type", type(group))
        
print(dic)
for name, group in grouped:
    key= name[0]
    value=name[1] 
    if(key in dic):
        dic[key].append(value)
    else:
        dic[key]=[value]
        
print (dic)
# Out:
# name  ('bar', 'one')
# group      A    B         C         D
# 1  bar  one -0.562686  0.921941
# type <class 'pandas.core.frame.DataFrame'>
# name  ('bar', 'three')
# group      A      B         C        D
# 3  bar  three -0.146382 -1.39776
# type <class 'pandas.core.frame.DataFrame'>
# name  ('bar', 'two')
# group      A    B         C         D
# 5  bar  two  0.006052 -1.100953
# type <class 'pandas.core.frame.DataFrame'>
# name  ('foo', 'four')
# group      A     B         C         D
# 7  foo  four -1.284365 -0.143604
# type <class 'pandas.core.frame.DataFrame'>
# name  ('foo', 'one')
# group      A    B         C         D
# 0  foo  one -0.347626  0.008619
# 6  foo  one  2.317197 -1.136477
# type <class 'pandas.core.frame.DataFrame'>
# name  ('foo', 'two')
# group      A    B         C         D
# 2  foo  two -0.016330  1.142171
# 4  foo  two  0.149273 -0.915715
# type <class 'pandas.core.frame.DataFrame'>
# {}
# {'bar': ['one', 'three', 'two'], 'foo': ['four', 'one', 'two']}

# %%
for name, group in grouped:
    print(name)
# Out:
# ('bar', 'one')
# ('bar', 'three')
# ('bar', 'two')
# ('foo', 'four')
# ('foo', 'one')
# ('foo', 'two')

# %%
grouped.groups.keys()
# Out:
# dict_keys([('bar', 'one'), ('bar', 'three'), ('bar', 'two'), ('foo', 'four'), ('foo', 'one'), ('foo', 'two')])

# %%
t = grouped.mean()

# %%
t
# Out:
#                   C         D
# A   B
# bar one   -0.562686  0.921941
#     three -0.146382 -1.397760
#     two    0.006052 -1.100953
# foo four  -1.284365 -0.143604
#     one    0.984786 -0.563929
#     two    0.066471  0.113228

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-22f19dc3b243> in <module>()
# ----> 1 t["A"]
#
# ...

# %%
data_pf =pd.read_csv('911-calls.csv')
data_pf.columns
# Out:
# Index(['Unnamed: 0', 'Call Number', 'Call Category', 'Call Group',
#        'Neighborhood', 'Report Date', 'Response Time (sec)',
#        'Time In Queue (sec)', 'Travel Time (sec)'],
#       dtype='object')

# %%
data_pf_index =pd.read_csv('911-calls.csv',index_col="Neighborhood")

# %%
data_pf_index.shape
# Out:
# (3844, 8)

# %%
data_pf_index.head()
# Out:
#                      Unnamed: 0  Call Number Call Category Call Group  \
# Neighborhood
# Hosford-Abernethy             0   2296401412        TriMet   Disorder
# Hosford-Abernethy             1   2392175033        TriMet   Disorder
# Hosford-Abernethy             2   2570595016        TriMet   Disorder
# Powellhurst-Gilbert           3   2188786224        TriMet   Disorder
# Foster-Powell                 4   2309187422        TriMet   Disorder
#
#                                Report Date  Response Time (sec)  \
# Neighborhood
# Hosford-Abernethy      7/4/2017 8:33:30 PM                 42.0
# Hosford-Abernethy    12/18/2017 7:13:27 PM                692.0
# Hosford-Abernethy     4/8/2018 10:25:38 AM               2193.0
# Powellhurst-Gilbert    9/2/2017 8:55:42 AM               1140.0
# Foster-Powell         8/5/2017 12:03:42 PM                797.0
#
#                      Time In Queue (sec)  Travel Time (sec)
# Neighborhood
# ...

# %%
#data.loc[(data["Gender"]=="Female") & (data["Education"]=="Not Graduate") & (data["Loan_Status"]=="Y"), ["Gender","Education","Loan_Status"]]

# %%
t = data_pf.loc[(data_pf["Neighborhood"]== "Hosford-Abernethy")]

# %%
t.head()
# Out:
#      Unnamed: 0  Call Number Call Category Call Group       Neighborhood  \
# 0             0   2296401412        TriMet   Disorder  Hosford-Abernethy
# 1             1   2392175033        TriMet   Disorder  Hosford-Abernethy
# 2             2   2570595016        TriMet   Disorder  Hosford-Abernethy
# 35           35   2203227522        TriMet   Disorder  Hosford-Abernethy
# 143         143   2177852612        TriMet   Disorder  Hosford-Abernethy
#
#                Report Date  Response Time (sec)  Time In Queue (sec)  \
# 0      7/4/2017 8:33:30 PM                 42.0                 42.0
# 1    12/18/2017 7:13:27 PM                692.0                 49.0
# 2     4/8/2018 10:25:38 AM               2193.0               1156.0
# 35     9/8/2017 4:30:29 PM                764.0                179.0
# 143   8/27/2017 7:46:28 PM                537.0                 83.0
#
#      Travel Time (sec)
# 0                  0.0
# 1                643.0
# 2               1037.0
# ...

# %%
def num_missing(x):
  return sum(x.isnull())

# %%
data_pf.apply(num_missing, axis=0)
# Out:
# Unnamed: 0               0
# Call Number              0
# Call Category            0
# Call Group               0
# Neighborhood           393
# Report Date              0
# Response Time (sec)    347
# Time In Queue (sec)      1
# Travel Time (sec)      346
# dtype: int64

# %%
print(type(v))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
v.head()
# Out:
#    Unnamed: 0  Call Number  Call Category  Call Group  Neighborhood  \
# 0       False        False          False       False         False
# 1       False        False          False       False         False
# 2       False        False          False       False         False
# 3       False        False          False       False         False
# 4       False        False          False       False         False
#
#    Report Date  Response Time (sec)  Time In Queue (sec)  Travel Time (sec)
# 0        False                False                False              False
# 1        False                False                False              False
# 2        False                False                False              False
# 3        False                False                False              False
# 4        False                False                False              False

# %%
from scipy.stats import mode

# %%
mode(data_pf['Response Time (sec)']).mode[0]
# Out:
# 260.0

# %%
print(data_pf.mode[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-5605ebdf4c7e> in <module>()
# ----> 1 print(data_pf.mode[0])
#
# TypeError: 'method' object is not subscriptable
